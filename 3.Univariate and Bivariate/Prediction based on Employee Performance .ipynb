# %%
import pandas as pd

# %%
dataset=pd.read_csv("Employee.csv")

# %%
dataset
# Out:
#            Department  Gender  Age   Job_Title  Years_At_Company  \
# 0                  IT    Male   55  Specialist                 2
# 1             Finance    Male   29   Developer                 0
# 2             Finance    Male   55  Specialist                 8
# 3    Customer Support  Female   48     Analyst                 7
# 4         Engineering  Female   36     Analyst                 3
# ..                ...     ...  ...         ...               ...
# 244                HR  Female   45     Manager                 4
# 245                IT  Female   32  Specialist                 2
# 246         Marketing  Female   24  Technician                 7
# 247                HR  Female   43     Analyst                 3
# 248             Legal    Male   32  Consultant                 2
#
#     Education_Level  Performance_Score  Monthly_Salary  Work_Hours_Per_Week  \
# 0       High School                5.0            6750                   33
# 1       High School                5.0            7500                   34
# 2       High School                3.0            5850                   37
# 3          Bachelor                2.0            4800                   52
# 4          Bachelor                2.0            4800                   38
# ..              ...                ...             ...                  ...
# 244        Bachelor                5.0            9000                   48
# 245        Bachelor                4.0            6300                   55
# 246        Bachelor                4.0            4900                   30
# 247        Bachelor                2.0            4800                   57
# 248     High School                3.0            7150                   35
#
#      Projects_Handled  Promotions  Resigned
# 0                  32           0     False
# 1                  34           2     False
# 2                  27           0     False
# 3                  10           1     False
# 4                  11           1     False
# ..                ...         ...       ...
# 244                 9           1     False
# 245                46           2     False
# 246                33           0     False
# 247                36           1     False
# 248                43           0     False
#
# [249 rows x 12 columns]

# %%
print(dataset.columns)
# Out:
# Index(['Department', 'Gender', 'Age', 'Job_Title', 'Years_At_Company',
#        'Education_Level', 'Performance_Score', 'Monthly_Salary',
#        'Work_Hours_Per_Week', 'Projects_Handled', 'Promotions', 'Resigned'],
#       dtype='object')

# %%
# Convert categorical columns to one-hot encoding
dataset = pd.get_dummies(dataset, columns=['Gender', 'Department', 'Status', 'Location', 'Session'], drop_first=True)

# %%
dataset
# Out:
#            Department  Gender  Age   Job_Title  Years_At_Company  \
# 0                  IT    Male   55  Specialist                 2
# 1             Finance    Male   29   Developer                 0
# 2             Finance    Male   55  Specialist                 8
# 3    Customer Support  Female   48     Analyst                 7
# 4         Engineering  Female   36     Analyst                 3
# ..                ...     ...  ...         ...               ...
# 244                HR  Female   45     Manager                 4
# 245                IT  Female   32  Specialist                 2
# 246         Marketing  Female   24  Technician                 7
# 247                HR  Female   43     Analyst                 3
# 248             Legal    Male   32  Consultant                 2
#
#     Education_Level  Performance_Score  Monthly_Salary  Work_Hours_Per_Week  \
# 0       High School                5.0            6750                   33
# 1       High School                5.0            7500                   34
# 2       High School                3.0            5850                   37
# 3          Bachelor                2.0            4800                   52
# 4          Bachelor                2.0            4800                   38
# ..              ...                ...             ...                  ...
# 244        Bachelor                5.0            9000                   48
# 245        Bachelor                4.0            6300                   55
# 246        Bachelor                4.0            4900                   30
# 247        Bachelor                2.0            4800                   57
# 248     High School                3.0            7150                   35
#
#      Projects_Handled  Promotions  Resigned
# 0                  32           0     False
# 1                  34           2     False
# 2                  27           0     False
# 3                  10           1     False
# 4                  11           1     False
# ..                ...         ...       ...
# 244                 9           1     False
# 245                46           2     False
# 246                33           0     False
# 247                36           1     False
# 248                43           0     False
#
# [249 rows x 12 columns]

# %%
# Convert categorical columns to one-hot encoding
categorical_columns = ['Gender', 'Department', 'Status', 'Location', 'Session']
dataset = pd.get_dummies(dataset, columns=categorical_columns, drop_first=True)

# Check the DataFrame after encoding
print(dataset.head())
print(dataset.dtypes)

# %%
dataset

# %%
dataset
# Out:
#            Department  Gender  Age   Job_Title  Years_At_Company  \
# 0                  IT    Male   55  Specialist                 2
# 1             Finance    Male   29   Developer                 0
# 2             Finance    Male   55  Specialist                 8
# 3    Customer Support  Female   48     Analyst                 7
# 4         Engineering  Female   36     Analyst                 3
# ..                ...     ...  ...         ...               ...
# 244                HR  Female   45     Manager                 4
# 245                IT  Female   32  Specialist                 2
# 246         Marketing  Female   24  Technician                 7
# 247                HR  Female   43     Analyst                 3
# 248             Legal    Male   32  Consultant                 2
#
#     Education_Level  Performance_Score  Monthly_Salary  Work_Hours_Per_Week  \
# 0       High School                5.0            6750                   33
# 1       High School                5.0            7500                   34
# 2       High School                3.0            5850                   37
# 3          Bachelor                2.0            4800                   52
# 4          Bachelor                2.0            4800                   38
# ..              ...                ...             ...                  ...
# 244        Bachelor                5.0            9000                   48
# 245        Bachelor                4.0            6300                   55
# 246        Bachelor                4.0            4900                   30
# 247        Bachelor                2.0            4800                   57
# 248     High School                3.0            7150                   35
#
#      Projects_Handled  Promotions  Resigned
# 0                  32           0     False
# 1                  34           2     False
# 2                  27           0     False
# 3                  10           1     False
# 4                  11           1     False
# ..                ...         ...       ...
# 244                 9           1     False
# 245                46           2     False
# 246                33           0     False
# 247                36           1     False
# 248                43           0     False
#
# [249 rows x 12 columns]

# %%
# Identify all columns with boolean data type
bool_columns = dataset.select_dtypes(include='bool').columns
# Convert boolean columns to integers (True -> 1, False -> 0)
dataset[bool_columns] = dataset[bool_columns].astype(int)
print(dataset.dtypes)
# Out:
# Department              object
# Gender                  object
# Age                      int64
# Job_Title               object
# Years_At_Company         int64
# Education_Level         object
# Performance_Score      float64
# Monthly_Salary           int64
# Work_Hours_Per_Week      int64
# Projects_Handled         int64
# Promotions               int64
# Resigned                 int32
# dtype: object

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 249 entries, 0 to 248
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Department           249 non-null    object
#  1   Gender               249 non-null    object
#  2   Age                  249 non-null    int64
#  3   Job_Title            249 non-null    object
#  4   Years_At_Company     249 non-null    int64
#  5   Education_Level      249 non-null    object
#  6   Performance_Score    221 non-null    float64
#  7   Monthly_Salary       249 non-null    int64
#  8   Work_Hours_Per_Week  249 non-null    int64
#  9   Projects_Handled     249 non-null    int64
#  10  Promotions           249 non-null    int64
#  11  Resigned             249 non-null    int32
# dtypes: float64(1), int32(1), int64(6), object(4)
# memory usage: 22.5+ KB

# %%
dataset.dtypes
# Out:
# Department              object
# Gender                  object
# Age                      int64
# Job_Title               object
# Years_At_Company         int64
# Education_Level         object
# Performance_Score      float64
# Monthly_Salary           int64
# Work_Hours_Per_Week      int64
# Projects_Handled         int64
# Promotions               int64
# Resigned                 int32
# dtype: object

# %% [markdown]
#  checking  for null values in a dataset

# %%
dataset.isnull().sum()
# Out:
# Department              0
# Gender                  0
# Age                     0
# Job_Title               0
# Years_At_Company        0
# Education_Level         0
# Performance_Score      28
# Monthly_Salary          0
# Work_Hours_Per_Week     0
# Projects_Handled        0
# Promotions              0
# Resigned                0
# dtype: int64

# %%
dataset.isna().sum()
# Out:
# Department              0
# Gender                  0
# Age                     0
# Job_Title               0
# Years_At_Company        0
# Education_Level         0
# Performance_Score      28
# Monthly_Salary          0
# Work_Hours_Per_Week     0
# Projects_Handled        0
# Promotions              0
# Resigned                0
# dtype: int64

# %%
dataset["Performance_Score"] = dataset["Performance_Score"].fillna(0)

# %%
#dataset["Performance Score"]
#dataset["Performance Score"].fillna(dataset["Performance Score"].median(),inplace=True)

# %%
dataset
# Out:
#            Department  Gender  Age   Job_Title  Years_At_Company  \
# 0                  IT    Male   55  Specialist                 2
# 1             Finance    Male   29   Developer                 0
# 2             Finance    Male   55  Specialist                 8
# 3    Customer Support  Female   48     Analyst                 7
# 4         Engineering  Female   36     Analyst                 3
# ..                ...     ...  ...         ...               ...
# 244                HR  Female   45     Manager                 4
# 245                IT  Female   32  Specialist                 2
# 246         Marketing  Female   24  Technician                 7
# 247                HR  Female   43     Analyst                 3
# 248             Legal    Male   32  Consultant                 2
#
#     Education_Level  Performance_Score  Monthly_Salary  Work_Hours_Per_Week  \
# 0       High School                5.0            6750                   33
# 1       High School                5.0            7500                   34
# 2       High School                3.0            5850                   37
# 3          Bachelor                2.0            4800                   52
# 4          Bachelor                2.0            4800                   38
# ..              ...                ...             ...                  ...
# 244        Bachelor                5.0            9000                   48
# 245        Bachelor                4.0            6300                   55
# 246        Bachelor                4.0            4900                   30
# 247        Bachelor                2.0            4800                   57
# 248     High School                3.0            7150                   35
#
#      Projects_Handled  Promotions  Resigned
# 0                  32           0         0
# 1                  34           2         0
# 2                  27           0         0
# 3                  10           1         0
# 4                  11           1         0
# ..                ...         ...       ...
# 244                 9           1         0
# 245                46           2         0
# 246                33           0         0
# 247                36           1         0
# 248                43           0         0
#
# [249 rows x 12 columns]

# %%
dataset.isnull().sum()
# Out:
# Department             0
# Gender                 0
# Age                    0
# Job_Title              0
# Years_At_Company       0
# Education_Level        0
# Performance_Score      0
# Monthly_Salary         0
# Work_Hours_Per_Week    0
# Projects_Handled       0
# Promotions             0
# Resigned               0
# dtype: int64

# %%
 dataset['Resigned'] = dataset['Resigned'].astype(str)

# %%
def quanQual(dataset):
    quan=[]
    qual=[]
    for columnName in dataset.columns:
        #print(columnName)
        if (dataset[columnName].dtype=='object'):
           # print("qual")
            qual.append(columnName)   
        else:
            #print("quan")
            quan.append(columnName)
    return quan,qual

# %%
quan,qual=quanQual(dataset)

# %%
qual
# Out:
# ['Department', 'Gender', 'Job_Title', 'Education_Level', 'Resigned']

# %%
quan
# Out:
# ['Age',
#  'Years_At_Company',
#  'Performance_Score',
#  'Monthly_Salary',
#  'Work_Hours_Per_Week',
#  'Projects_Handled',
#  'Promotions']

# %%
def freqTable(ColumnName,dataset):
        freqTable=pd.DataFrame(columns=["Unique_Values","Frequency","Relative Frequency","Cusum"])
        freqTable["Unique_Values"]=dataset[ColumnName].value_counts().index
        freqTable["Frequency"]=dataset[ColumnName].value_counts().values
        freqTable["Relative Frequency"]=(freqTable["Frequency"]/103)
        freqTable["Cusum"]=freqTable["Relative Frequency"].cumsum()
        return freqTable

# %%
freqTable("Monthly_Salary",dataset)
# Out:
#     Unique_Values  Frequency  Relative Frequency     Cusum
# 0            6600         23            0.223301  0.223301
# 1            8400         20            0.194175  0.417476
# 2            6000         16            0.155340  0.572816
# 3            4800         15            0.145631  0.718447
# 4            7800         15            0.145631  0.864078
# 5            9000         13            0.126214  0.990291
# 6            7200         10            0.097087  1.087379
# 7            4950         10            0.097087  1.184466
# 8            5250          9            0.087379  1.271845
# 9            7700          8            0.077670  1.349515
# 10           6750          8            0.077670  1.427184
# 11           5600          8            0.077670  1.504854
# 12           3850          8            0.077670  1.582524
# 13           4200          8            0.077670  1.660194
# 14           5850          8            0.077670  1.737864
# 15           6050          8            0.077670  1.815534
# 16           5400          7            0.067961  1.883495
# 17           5500          7            0.067961  1.951456
# 18           6300          7            0.067961  2.019417
# 19           6500          7            0.067961  2.087379
# 20           4400          7            0.067961  2.155340
# 21           4900          6            0.058252  2.213592
# 22           7150          5            0.048544  2.262136
# 23           5200          4            0.038835  2.300971
# 24           7500          4            0.038835  2.339806
# 25           4550          4            0.038835  2.378641
# 26           7000          3            0.029126  2.407767
# 27           8250          1            0.009709  2.417476

# %%
freqTable("Years_At_Company",dataset)
# Out:
#    Unique_Values  Frequency  Relative Frequency     Cusum
# 0              3         30            0.291262  0.291262
# 1              1         29            0.281553  0.572816
# 2              9         28            0.271845  0.844660
# 3              4         28            0.271845  1.116505
# 4              8         26            0.252427  1.368932
# 5              2         24            0.233010  1.601942
# 6              7         24            0.233010  1.834951
# 7              5         23            0.223301  2.058252
# 8              6         19            0.184466  2.242718
# 9              0         18            0.174757  2.417476

# %%
import numpy as np

# %%
descriptive=pd.DataFrame(index=["Mean","Median","Mode","Q1:25%","Q2:50%","Q3:75%","Q5:99%","Q4:100%","IQR","1.5Rule","Lesser","Greater","Max","Min","kurtosis","skew","Var","Std"],columns=quan)
for ColumnName in quan:
    descriptive.loc["Mean",ColumnName]=dataset[ColumnName].mean()
    descriptive.loc["Median",ColumnName]=dataset[ColumnName].median()
    descriptive.loc["Mode",ColumnName]=dataset[ColumnName].mode()[0]
    descriptive.loc["Q1:25%",ColumnName]=dataset[ColumnName].quantile(0.25)
    descriptive.loc["Q2:50%",ColumnName]=dataset[ColumnName].quantile(0.50)
    descriptive.loc["Q3:75%",ColumnName]=dataset[ColumnName].quantile(0.75)
    descriptive.loc["Q5:99%",ColumnName]=dataset[ColumnName].quantile(0.99)
    descriptive.loc["Q4:100%",ColumnName]=dataset[ColumnName].max()
    descriptive.loc["IQR",ColumnName]=descriptive.loc["Q3:75%",ColumnName]-descriptive.loc["Q1:25%",ColumnName]
    descriptive.loc["1.5Rule",ColumnName]=1.5*descriptive.loc["IQR",ColumnName]
    descriptive.loc["IQR",ColumnName]=descriptive.loc["Q3:75%",ColumnName]-descriptive.loc["Q1:25%",ColumnName]
    descriptive.loc["1.5Rule",ColumnName]=1.5*descriptive.loc["IQR",ColumnName]
    descriptive.loc["Lesser",ColumnName]=descriptive.loc["Q1:25%",ColumnName]-descriptive.loc["1.5Rule",ColumnName]
    descriptive.loc["Greater",ColumnName]=descriptive.loc["Q3:75%",ColumnName]+descriptive.loc["1.5Rule",ColumnName]
    descriptive.loc["Max",ColumnName]=dataset[ColumnName].max()
    descriptive.loc["Min",ColumnName]=dataset[ColumnName].min()
    descriptive.loc["kurtosis",ColumnName]=dataset[ColumnName].kurtosis()
    descriptive.loc["skew",ColumnName]=dataset[ColumnName].skew()
    descriptive.loc["Var",ColumnName]=dataset[ColumnName].var()
    descriptive.loc["Std",ColumnName]=dataset[ColumnName].std()

# %%
descriptive
# Out:
#                  Age Years_At_Company Performance_Score  Monthly_Salary  \
# Mean       40.156627         4.562249          2.751004     6307.831325
# Median          39.0              4.0               3.0          6050.0
# Mode              55                3               2.0            6600
# Q1:25%          30.0              2.0               2.0          5250.0
# Q2:50%          39.0              4.0               3.0          6050.0
# Q3:75%          50.0              7.0               4.0          7200.0
# Q5:99%          60.0              9.0               5.0          9000.0
# Q4:100%           60                9               5.0            9000
# IQR             20.0              5.0               2.0          1950.0
# 1.5Rule         30.0              7.5               3.0          2925.0
# Lesser           0.0             -5.5              -1.0          2325.0
# Greater         80.0             14.5               7.0         10125.0
# Max               60                9               5.0            9000
# Min               22                0               0.0            3850
# kurtosis   -1.209174         -1.23741         -0.918861       -0.854577
# skew        0.129865         0.063695         -0.194946        0.226631
# Var       122.906821         8.174537          2.397428  1919545.277886
# Std        11.086335         2.859115          1.548363     1385.476553
#
#          Work_Hours_Per_Week Projects_Handled Promotions
# Mean               44.413655        23.313253   0.983936
# Median                  44.0             24.0        1.0
# Mode                      53                9          0
# Q1:25%                  36.0             10.0        0.0
# Q2:50%                  44.0             24.0        1.0
# Q3:75%                  53.0             34.0        2.0
# Q5:99%                  59.0             49.0        2.0
# Q4:100%                   60               49          2
# IQR                     17.0             24.0        2.0
# 1.5Rule                 25.5             36.0        3.0
# Lesser                  10.5            -26.0       -3.0
# Greater                 78.5             70.0        5.0
# Max                       60               49          2
# Min                       30                0          0
# kurtosis           -1.317497         -1.11315  -1.523109
# skew                0.011917         0.161762   0.029867
# Var                80.348361       205.917606    0.67716
# Std                 8.963725        14.349829   0.822897

# %%
descriptive["Performance_Score"]["Lesser"]>descriptive["Performance_Score"]["Min"]
# Out:
# False

# %%
descriptive["Monthly_Salary"]["Min"]<descriptive["Monthly_Salary"]["Lesser"]
# Out:
# False

# %%
Lesser=[]
greater=[]
for ColumnName in quan:
    if(descriptive[ColumnName]["Min"]<descriptive[ColumnName]["Lesser"]):
        Lesser.append(ColumnName)
    if(descriptive[ColumnName]["Max"]>descriptive[ColumnName]["Greater"]):
        greater.append(ColumnName)

# %%
Lesser
# Out:
# []

# %%
greater
# Out:
# []

# %% [markdown]
# Finding outliers in the given dataset and replacing them

# %%
for ColumnName in Lesser:
    dataset[ColumnName][dataset[ColumnName]<descriptive[ColumnName]["Lesser"]]=descriptive[ColumnName]["Lesser"]
for ColumnName in greater:
    dataset[ColumnName][dataset[ColumnName]>descriptive[ColumnName]["Greater"]]=descriptive[ColumnName]["Greater"]

# %%
descriptive=pd.DataFrame(index=["Mean","Median","Mode","Q1:25%","Q2:50%","Q3:75%","Q5:99%","Q4:100%","IQR","1.5Rule","Lesser","Greater","Max","Min","kurtosis","skew","Var","Std"],columns=quan)
for ColumnName in quan:
    descriptive.loc["Mean",ColumnName]=dataset[ColumnName].mean()
    descriptive.loc["Median",ColumnName]=dataset[ColumnName].median()
    descriptive.loc["Mode",ColumnName]=dataset[ColumnName].mode()[0]
    descriptive.loc["Q1:25%",ColumnName]=dataset[ColumnName].quantile(0.25)
    descriptive.loc["Q2:50%",ColumnName]=dataset[ColumnName].quantile(0.50)
    descriptive.loc["Q3:75%",ColumnName]=dataset[ColumnName].quantile(0.75)
    descriptive.loc["Q5:99%",ColumnName]=dataset[ColumnName].quantile(0.99)
    descriptive.loc["Q4:100%",ColumnName]=dataset[ColumnName].max()
    descriptive.loc["IQR",ColumnName]=descriptive.loc["Q3:75%",ColumnName]-descriptive.loc["Q1:25%",ColumnName]
    descriptive.loc["1.5Rule",ColumnName]=1.5*descriptive.loc["IQR",ColumnName]
    descriptive.loc["IQR",ColumnName]=descriptive.loc["Q3:75%",ColumnName]-descriptive.loc["Q1:25%",ColumnName]
    descriptive.loc["1.5Rule",ColumnName]=1.5*descriptive.loc["IQR",ColumnName]
    descriptive.loc["Lesser",ColumnName]=descriptive.loc["Q1:25%",ColumnName]-descriptive.loc["1.5Rule",ColumnName]
    descriptive.loc["Greater",ColumnName]=descriptive.loc["Q3:75%",ColumnName]+descriptive.loc["1.5Rule",ColumnName]
    descriptive.loc["Max",ColumnName]=dataset[ColumnName].max()
    descriptive.loc["Min",ColumnName]=dataset[ColumnName].min()
    descriptive.loc["kurtosis",ColumnName]=dataset[ColumnName].kurtosis()
    descriptive.loc["skew",ColumnName]=dataset[ColumnName].skew()
    descriptive.loc["Var",ColumnName]=dataset[ColumnName].var()
    descriptive.loc["Std",ColumnName]=dataset[ColumnName].std()

# %%
descriptive
# Out:
#                  Age Years_At_Company Performance_Score  Monthly_Salary  \
# Mean       40.156627         4.562249          2.751004     6307.831325
# Median          39.0              4.0               3.0          6050.0
# Mode              55                3               2.0            6600
# Q1:25%          30.0              2.0               2.0          5250.0
# Q2:50%          39.0              4.0               3.0          6050.0
# Q3:75%          50.0              7.0               4.0          7200.0
# Q5:99%          60.0              9.0               5.0          9000.0
# Q4:100%           60                9               5.0            9000
# IQR             20.0              5.0               2.0          1950.0
# 1.5Rule         30.0              7.5               3.0          2925.0
# Lesser           0.0             -5.5              -1.0          2325.0
# Greater         80.0             14.5               7.0         10125.0
# Max               60                9               5.0            9000
# Min               22                0               0.0            3850
# kurtosis   -1.209174         -1.23741         -0.918861       -0.854577
# skew        0.129865         0.063695         -0.194946        0.226631
# Var       122.906821         8.174537          2.397428  1919545.277886
# Std        11.086335         2.859115          1.548363     1385.476553
#
#          Work_Hours_Per_Week Projects_Handled Promotions
# Mean               44.413655        23.313253   0.983936
# Median                  44.0             24.0        1.0
# Mode                      53                9          0
# Q1:25%                  36.0             10.0        0.0
# Q2:50%                  44.0             24.0        1.0
# Q3:75%                  53.0             34.0        2.0
# Q5:99%                  59.0             49.0        2.0
# Q4:100%                   60               49          2
# IQR                     17.0             24.0        2.0
# 1.5Rule                 25.5             36.0        3.0
# Lesser                  10.5            -26.0       -3.0
# Greater                 78.5             70.0        5.0
# Max                       60               49          2
# Min                       30                0          0
# kurtosis           -1.317497         -1.11315  -1.523109
# skew                0.011917         0.161762   0.029867
# Var                80.348361       205.917606    0.67716
# Std                 8.963725        14.349829   0.822897

# %% [markdown]
# Checking wether outlier has been replaced correctly

# %%
Lesser=[]
greater=[]
for ColumnName in quan:
    if(descriptive[ColumnName]["Min"]<descriptive[ColumnName]["Lesser"]):
        Lesser.append(ColumnName)
    if(descriptive[ColumnName]["Max"]>descriptive[ColumnName]["Greater"]):
        greater.append(ColumnName)

# %%
Lesser
# Out:
# []

# %%
greater
# Out:
# []

# %%
def Univariate(dataset,quan):
    descriptive=pd.DataFrame(index=["Mean","Median","Mode","Q1:25%","Q2:50%","Q3:75%","Q5:99%","Q4:100%","IQR","1.5Rule","Lesser","Greater","max","min","kurtosis","skew","Var","Std"],columns=quan)
    for ColumnName in quan:
        descriptive.loc["Mean",ColumnName]=dataset[ColumnName].mean()
        descriptive.loc["Median",ColumnName]=dataset[ColumnName].median()
        descriptive.loc["Mode",ColumnName]=dataset[ColumnName].mode()[0]
        descriptive.loc["Q1:25%",ColumnName]=dataset[ColumnName].quantile(0.25)
        descriptive.loc["Q2:50%",ColumnName]=dataset[ColumnName].quantile(0.50)
        descriptive.loc["Q3:75%",ColumnName]=dataset[ColumnName].quantile(0.75)
        descriptive.loc["Q5:99%",ColumnName]=dataset[ColumnName].quantile(0.99)
        descriptive.loc["Q4:100%",ColumnName]=dataset[ColumnName].max()
        descriptive.loc["IQR",ColumnName]=descriptive.loc["Q3:75%",ColumnName]-descriptive.loc["Q1:25%",ColumnName]
        descriptive.loc["1.5Rule",ColumnName]=1.5*descriptive.loc["IQR",ColumnName]
        descriptive.loc["IQR",ColumnName]=descriptive.loc["Q3:75%",ColumnName]-descriptive.loc["Q1:25%",ColumnName]
        descriptive.loc["1.5Rule",ColumnName]=1.5*descriptive.loc["IQR",ColumnName]
        descriptive.loc["Lesser",ColumnName]=descriptive.loc["Q1:25%",ColumnName]-descriptive.loc["1.5Rule",ColumnName]
        descriptive.loc["Greater",ColumnName]=descriptive.loc["Q3:75%",ColumnName]+descriptive.loc["1.5Rule",ColumnName]
        descriptive.loc["max",ColumnName]=dataset[ColumnName].max()
        descriptive.loc["min",ColumnName]=dataset[ColumnName].min()
        descriptive.loc["skew",ColumnName]=dataset[ColumnName].skew()
        descriptive.loc["Var",ColumnName]=dataset[ColumnName].var()
        descriptive.loc["Std",ColumnName]=dataset[ColumnName].std()
        descriptive.loc["kurtosis",ColumnName]=dataset[ColumnName].kurtosis()
        
    return descriptive

# %%
descriptive
# Out:
#                  Age Years_At_Company Performance_Score  Monthly_Salary  \
# Mean       40.156627         4.562249          2.751004     6307.831325
# Median          39.0              4.0               3.0          6050.0
# Mode              55                3               2.0            6600
# Q1:25%          30.0              2.0               2.0          5250.0
# Q2:50%          39.0              4.0               3.0          6050.0
# Q3:75%          50.0              7.0               4.0          7200.0
# Q5:99%          60.0              9.0               5.0          9000.0
# Q4:100%           60                9               5.0            9000
# IQR             20.0              5.0               2.0          1950.0
# 1.5Rule         30.0              7.5               3.0          2925.0
# Lesser           0.0             -5.5              -1.0          2325.0
# Greater         80.0             14.5               7.0         10125.0
# Max               60                9               5.0            9000
# Min               22                0               0.0            3850
# kurtosis   -1.209174         -1.23741         -0.918861       -0.854577
# skew        0.129865         0.063695         -0.194946        0.226631
# Var       122.906821         8.174537          2.397428  1919545.277886
# Std        11.086335         2.859115          1.548363     1385.476553
#
#          Work_Hours_Per_Week Projects_Handled Promotions
# Mean               44.413655        23.313253   0.983936
# Median                  44.0             24.0        1.0
# Mode                      53                9          0
# Q1:25%                  36.0             10.0        0.0
# Q2:50%                  44.0             24.0        1.0
# Q3:75%                  53.0             34.0        2.0
# Q5:99%                  59.0             49.0        2.0
# Q4:100%                   60               49          2
# IQR                     17.0             24.0        2.0
# 1.5Rule                 25.5             36.0        3.0
# Lesser                  10.5            -26.0       -3.0
# Greater                 78.5             70.0        5.0
# Max                       60               49          2
# Min                       30                0          0
# kurtosis           -1.317497         -1.11315  -1.523109
# skew                0.011917         0.161762   0.029867
# Var                80.348361       205.917606    0.67716
# Std                 8.963725        14.349829   0.822897

# %%
Univariate(dataset,quan)
# Out:
#                  Age Years_At_Company Performance_Score  Monthly_Salary  \
# Mean       40.156627         4.562249          2.751004     6307.831325
# Median          39.0              4.0               3.0          6050.0
# Mode              55                3               2.0            6600
# Q1:25%          30.0              2.0               2.0          5250.0
# Q2:50%          39.0              4.0               3.0          6050.0
# Q3:75%          50.0              7.0               4.0          7200.0
# Q5:99%          60.0              9.0               5.0          9000.0
# Q4:100%           60                9               5.0            9000
# IQR             20.0              5.0               2.0          1950.0
# 1.5Rule         30.0              7.5               3.0          2925.0
# Lesser           0.0             -5.5              -1.0          2325.0
# Greater         80.0             14.5               7.0         10125.0
# max               60                9               5.0            9000
# min               22                0               0.0            3850
# kurtosis   -1.209174         -1.23741         -0.918861       -0.854577
# skew        0.129865         0.063695         -0.194946        0.226631
# Var       122.906821         8.174537          2.397428  1919545.277886
# Std        11.086335         2.859115          1.548363     1385.476553
#
#          Work_Hours_Per_Week Projects_Handled Promotions
# Mean               44.413655        23.313253   0.983936
# Median                  44.0             24.0        1.0
# Mode                      53                9          0
# Q1:25%                  36.0             10.0        0.0
# Q2:50%                  44.0             24.0        1.0
# Q3:75%                  53.0             34.0        2.0
# Q5:99%                  59.0             49.0        2.0
# Q4:100%                   60               49          2
# IQR                     17.0             24.0        2.0
# 1.5Rule                 25.5             36.0        3.0
# Lesser                  10.5            -26.0       -3.0
# Greater                 78.5             70.0        5.0
# max                       60               49          2
# min                       30                0          0
# kurtosis           -1.317497         -1.11315  -1.523109
# skew                0.011917         0.161762   0.029867
# Var                80.348361       205.917606    0.67716
# Std                 8.963725        14.349829   0.822897

# %%
descriptive
# Out:
#                  Age Years_At_Company Performance_Score  Monthly_Salary  \
# Mean       40.156627         4.562249          2.751004     6307.831325
# Median          39.0              4.0               3.0          6050.0
# Mode              55                3               2.0            6600
# Q1:25%          30.0              2.0               2.0          5250.0
# Q2:50%          39.0              4.0               3.0          6050.0
# Q3:75%          50.0              7.0               4.0          7200.0
# Q5:99%          60.0              9.0               5.0          9000.0
# Q4:100%           60                9               5.0            9000
# IQR             20.0              5.0               2.0          1950.0
# 1.5Rule         30.0              7.5               3.0          2925.0
# Lesser           0.0             -5.5              -1.0          2325.0
# Greater         80.0             14.5               7.0         10125.0
# Max               60                9               5.0            9000
# Min               22                0               0.0            3850
# kurtosis   -1.209174         -1.23741         -0.918861       -0.854577
# skew        0.129865         0.063695         -0.194946        0.226631
# Var       122.906821         8.174537          2.397428  1919545.277886
# Std        11.086335         2.859115          1.548363     1385.476553
#
#          Work_Hours_Per_Week Projects_Handled Promotions
# Mean               44.413655        23.313253   0.983936
# Median                  44.0             24.0        1.0
# Mode                      53                9          0
# Q1:25%                  36.0             10.0        0.0
# Q2:50%                  44.0             24.0        1.0
# Q3:75%                  53.0             34.0        2.0
# Q5:99%                  59.0             49.0        2.0
# Q4:100%                   60               49          2
# IQR                     17.0             24.0        2.0
# 1.5Rule                 25.5             36.0        3.0
# Lesser                  10.5            -26.0       -3.0
# Greater                 78.5             70.0        5.0
# Max                       60               49          2
# Min                       30                0          0
# kurtosis           -1.317497         -1.11315  -1.523109
# skew                0.011917         0.161762   0.029867
# Var                80.348361       205.917606    0.67716
# Std                 8.963725        14.349829   0.822897

# %% [markdown]
#  # Univariate Analysis

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# 1. Age distribution
plt.figure(figsize=(8, 6))
sns.histplot(dataset['Age'], kde=True, bins=20, color='blue')
plt.title('Age Distribution')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# 2. Department frequency
plt.figure(figsize=(8, 6))
sns.countplot(x='Department', data=dataset, palette='viridis')
plt.title('Department Frequency')
plt.xlabel('Department')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.show()

# 3. Salary distribution
plt.figure(figsize=(8, 6))
sns.boxplot(x=dataset['Salary'], color='orange')
plt.title('Salary Distribution')
plt.xlabel('Salary')
plt.show()

# 4. Gender frequency
plt.figure(figsize=(8, 6))
sns.countplot(x='Gender', data=dataset, palette='pastel')
plt.title('Gender Distribution')
plt.xlabel('Gender')
plt.ylabel('Count')
plt.show()

# 5. Performance score count
plt.figure(figsize=(8, 6))
sns.countplot(x='Performance Score', data=dataset, palette='muted')
plt.title('Performance Score Distribution')
plt.xlabel('Performance Score')
plt.ylabel('Count')
plt.show()

# %%
['Department', 'Gender', 'Job_Title', 'Education_Level', 'Resigned']

# %%
['Age',
 'Years_At_Company',
 'Performance_Score',
 'Monthly_Salary',
 'Work_Hours_Per_Week',
 'Projects_Handled',
 'Promotions']

# %% [markdown]
# ## Univariate Analysis

# %% [raw]
# 1.What is the distribution of employee ages in dataset?

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(8, 6))
sns.histplot(dataset['Age'], bins=20, kde=True, color='skyblue')
plt.title('Age Distribution of Employees')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(8, 6))
sns.histplot(dataset['Age'], kde=True, bins=20,  color='skyblue')
plt.title('Age Distribution')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# %% [markdown]
# 2. What is the distribution of employees across different departments?

# %%
plt.figure(figsize=(8, 6))
sns.countplot(y='Department', data=dataset, palette='viridis')
plt.title('Employee Distribution Across Departments')
plt.xlabel('Count')
plt.ylabel('Department')
plt.show()
# Out:
# C:\Users\sindhiya maria\AppData\Local\Temp\ipykernel_18076\681374098.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(y='Department', data=dataset, palette='viridis')

# %% [markdown]
# 3. How is the performance score distributed among employees?

# %%
plt.figure(figsize=(8, 6))
sns.countplot(x='Performance_Score', data=dataset, palette='coolwarm')
plt.title('Performance Score Distribution')
plt.xlabel('Performance Score')
plt.ylabel('Count')
plt.show()
# Out:
# C:\Users\sindhiya maria\AppData\Local\Temp\ipykernel_18076\1713363814.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Performance_Score', data=dataset, palette='coolwarm')

# %% [markdown]
# 4. What is the distribution of monthly salaries?

# %%
plt.figure(figsize=(8, 6))
sns.histplot(dataset['Monthly_Salary'], bins=20, kde=True, color='purple')
plt.title('Monthly Salary Distribution')
plt.xlabel('Monthly Salary')
plt.ylabel('Frequency')
plt.show()

# %%
5. What is the distribution of the number of projects handled by employees?

# %%
plt.figure(figsize=(8, 6))
sns.histplot(dataset['Projects_Handled'], bins=15, kde=True, color='green')
plt.title('Distribution of Projects Handled')
plt.xlabel('Number of Projects')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
#  6. What is the impact of education level on monthly salary?

# %%
plt.figure(figsize=(8, 6))
sns.boxplot(x='Education_Level', y='Monthly_Salary', data=dataset, palette='viridis')
plt.title('Salary vs. Education Level')
plt.xlabel('Education Level')
plt.ylabel('Monthly Salary')
plt.show()
# Out:
# C:\Users\sindhiya maria\AppData\Local\Temp\ipykernel_18076\4153436590.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Education_Level', y='Monthly_Salary', data=dataset, palette='viridis')

# %%
 7. How many employees have resigned based on their job title?

# %%
plt.figure(figsize=(10, 6))
sns.countplot(y='Job_Title', hue='Resigned', data=dataset, palette='Set2')
plt.title('Resignation Count by Job Title')
plt.xlabel('Count')
plt.ylabel('Job Title')
plt.show()

# %% [markdown]
# 8. How do work hours affect performance scores?

# %%
plt.figure(figsize=(8, 6))
sns.scatterplot(x='Work_Hours_Per_Week', y='Performance_Score', data=dataset, hue='Gender', palette='coolwarm')
plt.title('Work Hours vs. Performance Score')
plt.xlabel('Work Hours per Week')
plt.ylabel('Performance Score')
plt.show()

# %%
 9. Which department has the highest number of employees?

# %%
plt.figure(figsize=(8, 6))
sns.countplot(y='Department', data=dataset, palette='magma')
plt.title('Employee Distribution by Department')
plt.xlabel('Count')
plt.ylabel('Department')
plt.show()
# Out:
# C:\Users\sindhiya maria\AppData\Local\Temp\ipykernel_18076\35777187.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(y='Department', data=dataset, palette='magma')

# %% [markdown]
# 10. How does the number of projects handled relate to promotions?

# %%
plt.figure(figsize=(8, 6))
sns.boxplot(x='Promotions', y='Projects_Handled', data=dataset, palette='cividis')
plt.title('Number of Projects Handled vs. Promotions')
plt.xlabel('Number of Promotions')
plt.ylabel('Projects Handled')
plt.show()
# Out:
# C:\Users\sindhiya maria\AppData\Local\Temp\ipykernel_18076\3706030051.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Promotions', y='Projects_Handled', data=dataset, palette='cividis')

# %% [markdown]
# Bivariate Analysis

# %% [markdown]
# 1.What is the relationship between education level and salary?

# %%
plt.figure(figsize=(8, 6))
sns.boxplot(x='Education_Level', y='Monthly_Salary', data=dataset, palette='magma')
plt.title('Education Level vs Monthly Salary')
plt.xlabel('Education Level')
plt.ylabel('Monthly Salary')
plt.show()
# Out:
# C:\Users\sindhiya maria\AppData\Local\Temp\ipykernel_18076\3603960757.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Education_Level', y='Monthly_Salary', data=dataset, palette='magma')

# %% [markdown]
# 2.How does experience at the company (Years_At_Company) relate to salary?

# %%
plt.figure(figsize=(8, 6))
sns.scatterplot(x='Years_At_Company', y='Monthly_Salary', data=dataset, hue='Performance_Score', palette='coolwarm')
plt.title('Years at Company vs Monthly Salary')
plt.xlabel('Years at Company')
plt.ylabel('Monthly Salary')
plt.show()

# %% [markdown]
# 3.Does work hours per week impact performance score?

# %%
plt.figure(figsize=(8, 6))
sns.boxplot(x='Performance_Score', y='Work_Hours_Per_Week', data=dataset, palette='Blues')
plt.title('Performance Score vs Work Hours Per Week')
plt.xlabel('Performance Score')
plt.ylabel('Work Hours Per Week')
plt.show()
# Out:
# C:\Users\sindhiya maria\AppData\Local\Temp\ipykernel_18076\945847964.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Performance_Score', y='Work_Hours_Per_Week', data=dataset, palette='Blues')

# %% [markdown]
# 4.How does the number of projects handled relate to salary?

# %%
plt.figure(figsize=(8, 6))
sns.scatterplot(x='Projects_Handled', y='Monthly_Salary', data=dataset, hue='Department', palette='Set1')
plt.title('Projects Handled vs Monthly Salary')
plt.xlabel('Number of Projects Handled')
plt.ylabel('Monthly Salary')
plt.show()

# %% [markdown]
# 5.What is the resignation trend based on department?

# %%
plt.figure(figsize=(8, 6))
sns.countplot(y='Department', hue='Resigned', data=dataset, palette='coolwarm')
plt.title('Resignation Trend by Department')
plt.xlabel('Count')
plt.ylabel('Department')
plt.legend(title='Resigned', labels=['No', 'Yes'])
plt.show()

# %% [markdown]
# ## 6 )What kind of relation between Salary and Years_At_Company ?

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Calculate the Pearson correlation coefficient between salary and mba_p
correlation = dataset['Monthly_Salary'].corr(dataset['Years_At_Company'])
print(f'Correlation between Salary and Performance Score: {correlation:}')

# Scatter plot with regression line
plt.figure(figsize=(10, 6))
sns.scatterplot(data=dataset, x='Years_At_Company', y='Monthly_Salary')
sns.regplot(data=dataset, x='Years_At_Company', y='Monthly_Salary', scatter=False, color='red')
plt.title('Relationship between Experience and Monthly_Salary')
plt.xlabel('Years_At_Company')
plt.ylabel('Monthly_Salary')
plt.grid(True)
plt.show()


correlation = dataset['Monthly_Salary'].corr(dataset['Years_At_Company'])
# Out:
# Correlation between Salary and Performance Score: -0.028192958806938898

# %% [markdown]
# # 7) Which specialization is getting minimum salary?

# %%
# Group by 'department' and calculate the minimum salary for each group
min_salary_by_department = dataset.groupby('Years_At_Company')['Monthly_Salary'].min()

# Print the result
print(min_salary_by_department)

# Find the specialization with the overall minimum salary
min_department = min_salary_by_department.idxmin()
min_salary = min_salary_by_department.min()

print(f"The  department with the minimum salary is: {min_department}")
print(f"The minimum salary is: {min_salary}")
# Out:
# Years_At_Company
# 0    4200
# 1    4200
# 2    3850
# 3    4400
# 4    3850
# 5    3850
# 6    3850
# 7    3850
# 8    4200
# 9    3850
# Name: Monthly_Salary, dtype: int64
# The  department with the minimum salary is: 2
# The minimum salary is: 3850

# %% [markdown]
#  8. How many of them getting salary > 9000?

# %%
# Filter the dataset for salaries above 500,000 and get the count directly
num_high_salary = dataset[dataset['Monthly_Salary'] > 8000].shape[0]

print(f"Number of individuals with Monthly_Salary above 8000: {num_high_salary}")
# Out:
# Number of individuals with Monthly_Salary above 8000: 34

# %% [markdown]
# 9.What is the probability density fucntion of salary between 7000 to 9000?

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from scipy.stats import norm

# Extract the salary column
salary = dataset['Monthly_Salary']

# Plot the Probability Density Function (PDF) of the salary column
plt.figure(figsize=(10, 6))
sns.kdeplot(salary, fill=True)
plt.xlabel('Monthly_Salary')
plt.ylabel('Probability Density')
plt.title('Probability Density Function of Salary')
plt.grid(True)
plt.show()

# Fit a normal distribution to the salary data
mean_salary = salary.mean()
std_salary = salary.std()

# Define the range for plotting the PDF
x = np.linspace(6000, 9000, 100)
pdf = norm.pdf(x, mean_salary, std_salary)

# Plot the probability density for the range
plt.figure(figsize=(10, 6))
plt.plot(x, pdf, label='PDF of Salary')
plt.fill_between(x, pdf, where=(x >= 6000) & (x <= 9000), color='red', alpha=0.5, label='Range 6000 to 9000')
plt.xlabel('Monthly_Salary')
plt.ylabel('Probability Density')
plt.title('Probability Density Function of Salary in Range 700,000 to 900,000')
plt.legend()
plt.grid(True)
plt.show()

# Calculate the probability for the range 700,000 to 900,000
cdf_lower = norm.cdf(7000, mean_salary, std_salary)
cdf_upper = norm.cdf(9000, mean_salary, std_salary)
probability = cdf_upper - cdf_lower

# Print the probability
print(f"The probability of salary being between 700,000 and 900,000 is: {probability:.5f}")
# Out:
# The probability of salary being between 700,000 and 900,000 is: 0.28268

# %% [markdown]
# 10.How does age vary across different departments?

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x='Department', y='Age', data=dataset, palette='Set2')
plt.title('Age Distribution by Department')
plt.xlabel('Department')
plt.ylabel('Age')
plt.grid(True)
plt.show()
# Out:
# C:\Users\sindhiya maria\AppData\Local\Temp\ipykernel_18076\1093412257.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Department', y='Age', data=dataset, palette='Set2')

# %% [markdown]
# 11.What is the relationship between salary and performance score?

# %%
print(dataset.columns)
# Out:
# Index(['Department', 'Gender', 'Age', 'Job_Title', 'Years_At_Company',
#        'Education_Level', 'Performance_Score', 'Monthly_Salary',
#        'Work_Hours_Per_Week', 'Projects_Handled', 'Promotions', 'Resigned'],
#       dtype='object')

# %%
plt.figure(figsize=(8, 6))

sns.scatterplot(x='Performance_Score', y='Monthly_Salary', data=dataset, hue='Department', palette='coolwarm')
plt.title('Salary vs Performance Score')
plt.xlabel('Performance Score')
plt.ylabel('Monthly_Salary')
plt.show()

# %% [markdown]
# 12.How does gender impact performance scores?

# %%
plt.figure(figsize=(8, 6))
sns.boxplot(x='Gender', y='Performance_Score', data=dataset, palette='pastel',hue = 'Promotions')
plt.title('Performance Score by Gender')
plt.xlabel('Gender')
plt.ylabel('Performance_Score')
plt.show()

# %% [markdown]
# 13.What is the relationship between experience and salary?

# %%
plt.figure(figsize=(8, 6))
sns.scatterplot(x='Years_At_Company', y='Monthly_Salary', data=dataset, hue='Gender', palette='coolwarm')
plt.title('Years_At_Company vs Monthly_Salary')
plt.xlabel('Years_At_Company (Years)')
plt.ylabel('Monthly_Salary')
plt.grid(True)
plt.show()

# %%
14.which parameter is highly correlated with salary?

# %%
import pandas as pd

# Assuming 'dataset' is your DataFrame
quan, qual = quanQual(dataset)

# Filter numerical columns for correlation calculation
numerical_columns = [col for col in quan if col in ['ID', 'Age', 'Monthly_Salary', 'Performance_Score', 'Years_At_Company']]

# Calculate the correlation matrix for the numerical values
correlation_matrix = dataset[numerical_columns].corr()

# Extract the correlation values with 'salary', excluding 'salary' itself
salary_correlation = correlation_matrix['Monthly_Salary'].drop('Monthly_Salary')

# Find the parameter with the highest correlation with salary
most_correlated_parameter = salary_correlation.idxmax()
highest_correlation_value = salary_correlation.max()

# Print the results
print(f"The parameter most highly correlated with salary is: {most_correlated_parameter}")
print(f"The correlation coefficient is: {highest_correlation_value:.4f}")
# Out:
# The parameter most highly correlated with salary is: Performance_Score
# The correlation coefficient is: 0.5316

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming 'dataset' is your DataFrame
quan, qual = quanQual(dataset)

# Filter numerical columns for correlation calculation
numerical_columns = [col for col in quan if col in ['ID', 'Age', 'Monthly_Salary', 'Performance_Score', 'Years_At_Company']]

# Calculate the correlation matrix for the numerical values
correlation_matrix = dataset[numerical_columns].corr()

# Plotting the heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f",vmin=-1, vmax=1)
plt.title('Correlation Matrix Heatmap')
plt.show()

# %%
sns.pairplot(dataset)

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

def calc_vif(X):

    # Calculating VIF
    vif = pd.DataFrame()
    vif["variables"] = X.columns
    vif["VIF"] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]

    return(vif)

# %%
calc_vif(dataset[quan])
# Out:
#              variables        VIF
# 0                  Age  12.200921
# 1     Years_At_Company   3.502669
# 2    Performance_Score   5.851043
# 3       Monthly_Salary  22.224277
# 4  Work_Hours_Per_Week  17.763886
# 5     Projects_Handled   3.471518
# 6           Promotions   2.502670

# %%
calc_vif(dataset[["Age","Monthly_Salary","Performance_Score","Years_At_Company"]])
# Out:
#            variables        VIF
# 0                Age   9.835581
# 1     Monthly_Salary  16.506530
# 2  Performance_Score   5.832880
# 3   Years_At_Company   3.394460

# %%
calc_vif(dataset[["Monthly_Salary","Performance_Score","Years_At_Company"]])
# Out:
#            variables       VIF
# 0     Monthly_Salary  8.122141
# 1  Performance_Score  5.675561
# 2   Years_At_Company  3.138342

# %%
calc_vif(dataset[["Monthly_Salary","Performance_Score","Years_At_Company"]])
# Out:
#            variables       VIF
# 0     Monthly_Salary  8.122141
# 1  Performance_Score  5.675561
# 2   Years_At_Company  3.138342

# %%
calc_vif(dataset[["Years_At_Company","Performance_Score"]])
# Out:
#            variables       VIF
# 0   Years_At_Company  2.187612
# 1  Performance_Score  2.187612

# %%
calc_vif(dataset[["Years_At_Company","Monthly_Salary"]])
# Out:
#           variables       VIF
# 0  Years_At_Company  3.130633
# 1    Monthly_Salary  3.130633

# %% [markdown]
# InDependent sample - unpaired T test
#
# Different Group('M','F') but same condition (Salary)

# %%
from scipy.stats import ttest_ind
dataset= dataset.dropna()
male= dataset[dataset['Gender']=='Male']['Monthly_Salary']
female=dataset[dataset['Gender']=='Female']['Monthly_Salary']

#print(male)
ttest_ind(male,female)
# Out:
# TtestResult(statistic=0.9808223737884251, pvalue=0.32768051060733927, df=237.0)

# %%
dataset[dataset['Gender']=='Male']['Monthly_Salary']
# Out:
# 0      6750
# 1      7500
# 2      5850
# 5      7800
# 6      5250
#        ...
# 237    8400
# 240    6500
# 241    6600
# 242    6000
# 248    7150
# Name: Monthly_Salary, Length: 125, dtype: int64

# %%
dataset[dataset['Gender']=='Female']['Monthly_Salary']
# Out:
# 3      4800
# 4      4800
# 7      7200
# 8      4200
# 9      6050
#        ...
# 243    4800
# 244    9000
# 245    6300
# 246    4900
# 247    4800
# Name: Monthly_Salary, Length: 114, dtype: int64
